# %%
import cv2
import os
import numpy as np
from pathlib import Path
import mmcv
from tqdm import tqdm
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
list(Path(img_path).parent.glob('*.mp4'))
# Out:
# [PosixPath('../data/larp/sjtu_larp_cloudy/reverse2/positive_video/VID_20230317_155922.mp4'),
#  PosixPath('../data/larp/sjtu_larp_cloudy/reverse2/positive_video/VID_20230317_160036.mp4')]

# %%
img_path = '../data/larp/sjtu_larp_cloudy/reverse2/positive_video/VID_20230317_160036_260.png'

# %%
img = cv2.imread(img_path)
plt.imshow(img)

# %%
img_rot = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
plt.imshow(img_rot)

# %%
img_dir = Path(img_path).parent
issue_list = list(img_dir.glob('VID_20230317_160036*.png'))

# %%
for path in tqdm(issue_list):
    im = cv2.imread(str(path))
    im_rot = cv2.rotate(im, cv2.ROTATE_90_CLOCKWISE)
    cv2.imwrite(str(path), im_rot)
# Out:
# 100%|██████████| 30/30 [00:04<00:00,  7.30it/s]

# %%
img = cv2.imread('../tmp/vis_data/')

# %%
plt.imshow
# Out:
# (1380, 1235, 3)
